# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import re
from matplotlib import style
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_absolute_error, r2_score
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score

# %%
Data = pd.read_csv('DONNEE REDUCTUCTEUR.csv', sep=';')
Data.head()
# Out:
#       time  amplitude-XP1  amplitude-YP1  amplitude-ZP1  amplitude-XP2  \
# 0  0.00000        0.17003        0.09006        0.98467        0.17977
# 1  0.01526        0.16947        0.08977        0.98148        0.17918
# 2  0.03052        0.16893        0.08948        0.97830        0.17860
# 3  0.04578        0.16838        0.08919        0.97513        0.17802
# 4  0.06104        0.16783        0.08890        0.97197        0.17745
#
#    amplitude-YP2  amplitude-ZP2  amplitude-XP3  amplitude-YP3  amplitude-ZP3  \
# 0        0.25221         1.0987        0.06829        0.17083        0.16087
# 1        0.25139         1.0951        0.07465        0.17028        0.16035
# 2        0.25058         1.0916        0.08211        0.16973        0.15983
# 3        0.24976         1.0880        0.09291        0.16918        0.15931
# 4        0.24895         1.0845        0.10398        0.16863        0.15879
#
#    ...  amplitude-ZP5INF  amplitude-XP6SUP  amplitude-YP6SUP  \
# ...

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 131072 entries, 0 to 131071
# Data columns (total 28 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   time              131072 non-null  float64
#  1   amplitude-XP1     131072 non-null  float64
#  2   amplitude-YP1     131072 non-null  float64
#  3   amplitude-ZP1     131072 non-null  float64
#  4   amplitude-XP2     131072 non-null  float64
#  5   amplitude-YP2     131072 non-null  float64
#  6   amplitude-ZP2     131072 non-null  float64
#  7   amplitude-XP3     131072 non-null  float64
#  8   amplitude-YP3     131072 non-null  float64
#  9   amplitude-ZP3     131072 non-null  float64
#  10  amplitude-XP4INF  131072 non-null  float64
#  11  amplitude-YP4INF  131072 non-null  float64
#  12  amplitude-ZP4INF  131072 non-null  float64
#  13  amplitude-XP4SUP  131072 non-null  float64
#  14  amplitude-YP4SUP  131072 non-null  float64
# ...

# %%
#Correlation matrix

plt.figure(figsize=(20,14))
sns.heatmap(Data.corr(), annot=True)
plt.title("Correlation between columns")
plt.show()

# %%
Data.corr()['time'].sort_values()
# Out:
# amplitude-YP2      -0.097120
# amplitude-XP1      -0.091125
# amplitude-XP2      -0.076737
# amplitude-ZP4INF   -0.056807
# amplitude-ZP1      -0.047098
# amplitude-ZP3      -0.034271
# amplitude-XP7INF   -0.033156
# amplitude-ZP5INF   -0.032750
# amplitude-YP4INF   -0.029734
# aplitude-YP8SUP    -0.024751
# amplitude-XP3      -0.018952
# amplitude-YP7INF   -0.017957
# amplitude-YP4SUP   -0.014721
# amplitude-YP3      -0.012758
# amplitude-YP1      -0.011516
# amplitude-XP4INF   -0.005807
# amplitude-YP5INF    0.014370
# amplitude-ZP2       0.021661
# amplitude-ZP4SUP    0.027969
# amplitude-YP6SUP    0.029147
# amplitude-XP5INF    0.040586
# amplitude-ZP7INF    0.041419
# amplitude-XP6SUP    0.052579
# amplitude-ZP8SUP    0.057801
# amplitude-ZP6SUP    0.060609
# amplitude-XP8SUP    0.065966
# amplitude-XP4SUP    0.089164
# time                1.000000
# Name: time, dtype: float64

# %%
plt.figure(figsize=(20,8))

plt.subplot(1,2,1)
plt.title('time Distribution Plot')
sns.distplot(Data.time)

plt.subplot(1,2,2)
plt.title('time Spread')
sns.boxplot(y=Data.time)

plt.show()
# Out:
# C:\Users\Angeleco\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
## Print vibration from bearing at first day
fig, ax1 = plt.subplots(1,1, figsize=(16, 5))
Data[['amplitude-XP1']].plot(figsize=(18,6), ax=ax1)
Data[['amplitude-XP2']].plot(figsize=(18,6), ax=ax1)
Data[['amplitude-XP3']].plot(figsize=(18,6), ax=ax1)
Data[['amplitude-XP4INF']].plot(figsize=(18,6), ax=ax1)
Data[['amplitude-XP4SUP']].plot(figsize=(18,6), ax=ax1)
Data[['amplitude-XP5INF']].plot(figsize=(18,6), ax=ax1)
Data[['amplitude-XP6SUP']].plot(figsize=(18,6), ax=ax1)
Data[['amplitude-XP7INF']].plot(figsize=(18,6), ax=ax1)
Data[['amplitude-XP8SUP']].plot(figsize=(18,6), ax=ax1)
plt.tight_layout()

# %%
fig, ax1 = plt.subplots(1,1, figsize=(16, 5))
Data[['amplitude-YP1']].plot(figsize=(18,6), ax=ax1)
Data[['amplitude-YP2']].plot(figsize=(18,6), ax=ax1)
Data[['amplitude-YP3']].plot(figsize=(18,6), ax=ax1)
Data[['amplitude-YP4INF']].plot(figsize=(18,6), ax=ax1)
Data[['amplitude-YP4SUP']].plot(figsize=(18,6), ax=ax1)
Data[['amplitude-YP5INF']].plot(figsize=(18,6), ax=ax1)
Data[['amplitude-YP6SUP']].plot(figsize=(18,6), ax=ax1)
Data[['amplitude-YP7INF']].plot(figsize=(18,6), ax=ax1)
Data[['aplitude-YP8SUP']].plot(figsize=(18,6), ax=ax1)
plt.tight_layout()

# %%
fig, ax1 = plt.subplots(1,1, figsize=(16, 5))
Data[['amplitude-ZP1']].plot(figsize=(18,6), ax=ax1)
Data[['amplitude-ZP2']].plot(figsize=(18,6), ax=ax1)
Data[['amplitude-ZP3']].plot(figsize=(18,6), ax=ax1)
Data[['amplitude-ZP4INF']].plot(figsize=(18,6), ax=ax1)
Data[['amplitude-ZP4SUP']].plot(figsize=(18,6), ax=ax1)
Data[['amplitude-ZP5INF']].plot(figsize=(18,6), ax=ax1)
Data[['amplitude-ZP6SUP']].plot(figsize=(18,6), ax=ax1)
Data[['amplitude-ZP7INF']].plot(figsize=(18,6), ax=ax1)
Data[['amplitude-ZP8SUP']].plot(figsize=(18,6), ax=ax1)
plt.tight_layout()

# %%
fig, ax1 = plt.subplots(1,1, figsize=(16, 5))
Data[['amplitude-XP1']].plot(figsize=(18,6), ax=ax1)
Data[['amplitude-XP2']].plot(figsize=(18,6), ax=ax1)
Data[['amplitude-XP3']].plot(figsize=(18,6), ax=ax1)
Data[['amplitude-XP4INF']].plot(figsize=(18,6), ax=ax1)
Data[['amplitude-XP4SUP']].plot(figsize=(18,6), ax=ax1)
Data[['amplitude-XP5INF']].plot(figsize=(18,6), ax=ax1)
Data[['amplitude-XP6SUP']].plot(figsize=(18,6), ax=ax1)
Data[['amplitude-XP7INF']].plot(figsize=(18,6), ax=ax1)
Data[['amplitude-XP8SUP']].plot(figsize=(18,6), ax=ax1)
Data[['amplitude-YP1']].plot(figsize=(18,6), ax=ax1)
Data[['amplitude-YP2']].plot(figsize=(18,6), ax=ax1)
Data[['amplitude-YP3']].plot(figsize=(18,6), ax=ax1)
Data[['amplitude-YP4INF']].plot(figsize=(18,6), ax=ax1)
Data[['amplitude-YP4SUP']].plot(figsize=(18,6), ax=ax1)
Data[['amplitude-YP5INF']].plot(figsize=(18,6), ax=ax1)
Data[['amplitude-YP6SUP']].plot(figsize=(18,6), ax=ax1)
Data[['amplitude-YP7INF']].plot(figsize=(18,6), ax=ax1)
Data[['aplitude-YP8SUP']].plot(figsize=(18,6), ax=ax1)
Data[['amplitude-ZP1']].plot(figsize=(18,6), ax=ax1)
Data[['amplitude-ZP2']].plot(figsize=(18,6), ax=ax1)
Data[['amplitude-ZP3']].plot(figsize=(18,6), ax=ax1)
Data[['amplitude-ZP4INF']].plot(figsize=(18,6), ax=ax1)
Data[['amplitude-ZP4SUP']].plot(figsize=(18,6), ax=ax1)
Data[['amplitude-ZP5INF']].plot(figsize=(18,6), ax=ax1)
Data[['amplitude-ZP6SUP']].plot(figsize=(18,6), ax=ax1)
Data[['amplitude-ZP7INF']].plot(figsize=(18,6), ax=ax1)
Data[['amplitude-ZP8SUP']].plot(figsize=(18,6), ax=ax1)
plt.tight_layout()

# %%
d1=Data.head(16384)

# %%
df = d1["amplitude-XP1"]
N= len(df)
y=[]
for j in range(0,(int(N/2)+1)):
    R=0    
    for i in range(0,(int(N/2))):
        R = R+ df[i]*df[i+j]
    y.append(R*2/N)
    
# Autocorrelation coefficient calculation

df = pd.DataFrame(y)
df.columns =['R']
R0=df.iloc[0,0]
R0
df['A'] = df['R']/R0
dt = d1["time"]
t=[]
for i in range(len(df)):
    t.append(dt[i])
    
df['t']=t
# Plot waveform signal
fig = plt.figure(figsize=(8,8), dpi=72)
x=d1["time"]
y=d1["amplitude-XP1"]
plt.plot(x,y)
plt.xlabel("Time")
plt.ylabel("amplitude-XP1")
plt.title("Original Signal waveform")
fig.savefig("Signal wave form.png")
plt.grid()
# Plot figure of Autocorrelation coefficient
fig1 = plt.figure(figsize=(8,8), dpi=72)
x1=df["t"]
y1=df["A"]
plt.plot(x1,y1)
plt.xlabel("Time[ms]")
plt.ylabel("Amplitude[g]")
plt.title("Autocorrelation coefficient")
fig1.savefig("Autocorrelation coefficient.png")
plt.grid()

# %%
from numpy.fft import fft, fftfreq

N=df.size # Number of samples

Duration =0,12 # Length of the wavwform in second(Duration)
Te = 1/16384 # Sampling time

X = fft(df)  # Fast Fourier Transform

freq = fftfreq(df.size, 1/16384)  # Fast Fourier Transform Frequency

# Take only positif absolute value and  normalisation

X_abs = np.abs(X[:N//2])*2.0/N

freq_pos = freq[:N//2]

peakX = np.max(X_abs) # Find max peak

locX = np.argmax(X_abs) # Find its location

freq_posX = freq_pos[locX] # Get the actual frequency value

# New - Plot the max point
#plt.plot(freq_posX, peakX, 'r.', markersize=9)


fig = plt.figure(figsize=(10,7))

plt.plot(freq_posX, peakX, 'r.', markersize=9)

freq_pos = freq[:N//2]
plt.plot(freq_pos, X_abs, label="Amplitude absolue")
plt.xlim(1, 450)  # zoom frequency
plt.ylim(0, 0.15)
plt.grid()
plt.xlabel("Fréquence (Hz)")
plt.ylabel("Amplitude |X(f)| [mm/s]_RMS")

plt.show()
fig.savefig("Spectre FFT")

# %%
df = d1["amplitude-XP8SUP"]
N= len(df)
y=[]
for j in range(0,(int(N/2)+1)):
    R=0    
    for i in range(0,(int(N/2))):
        R = R+ df[i]*df[i+j]
    y.append(R*2/N)
    
# Autocorrelation coefficient calculation

df = pd.DataFrame(y)
df.columns =['R']
R0=df.iloc[0,0]
R0
df['A'] = df['R']/R0
dt = d1["time"]
t=[]
for i in range(len(df)):
    t.append(dt[i])
    
df['t']=t
# Plot waveform signal
fig = plt.figure(figsize=(8,8), dpi=72)
x=d1["time"]
y2=d1["amplitude-XP8SUP"]
plt.plot(x,y2)
plt.xlabel("Time")
plt.ylabel("amplitude-XP8SUP")
plt.title("Original Signal waveform")
fig.savefig("Signal wave form.png")
plt.grid()
# Plot figure of Autocorrelation coefficient
fig1 = plt.figure(figsize=(8,8), dpi=72)
x1=df["t"]
y1=df["A"]
plt.plot(x1,y1)
plt.xlabel("Time[ms]")
plt.ylabel("Amplitude[g]")
plt.title("Autocorrelation coefficient")
fig1.savefig("Autocorrelation coefficient.png")
plt.grid()

# %%
from numpy.fft import fft, fftfreq

N=y2.size # Number of samples

Duration =0,12 # Length of the wavwform in second(Duration)
Te = 1/16384 # Sampling time

X = fft(y2)  # Fast Fourier Transform

freq = fftfreq(y2.size, 1/16384)  # Fast Fourier Transform Frequency

# Take only positif absolute value and  normalisation

X_abs = np.abs(X[:N//2])*2.0/N

freq_pos = freq[:N//2]

peakX = np.max(X_abs) # Find max peak

locX = np.argmax(X_abs) # Find its location

freq_posX = freq_pos[locX] # Get the actual frequency value


# New - Plot the max point
#plt.plot(freq_posX, peakX, 'r.', markersize=9)


fig = plt.figure(figsize=(10,7))

plt.plot(freq_posX, peakX, 'r.', markersize=9)

freq_pos = freq[:N//2]
plt.plot(freq_pos, X_abs, label="Amplitude absolue")
plt.xlim(1, 450)  # zoom frequency
plt.ylim(0, 0.15)
plt.grid()
plt.xlabel("Fréquence (Hz)")
plt.ylabel("Amplitude |X(f)| [mm/s]_RMS")

plt.show()
fig.savefig("Spectre FFT")

# %%
from numpy.fft import fft, fftfreq

N=y1.size # Number of samples

Duration =0,12 # Length of the wavwform in second(Duration)
Te = 1/16384 # Sampling time

X = fft(y1)  # Fast Fourier Transform

freq = fftfreq(y1.size, 1/16384)  # Fast Fourier Transform Frequency

# Take only positif absolute value and  normalisation

X_abs = np.abs(X[:N//2])*2.0/N

freq_pos = freq[:N//2]

peakX = np.max(X_abs) # Find max peak

locX = np.argmax(X_abs) # Find its location

freq_posX = freq_pos[locX] # Get the actual frequency value


# New - Plot the max point
#plt.plot(freq_posX, peakX, 'r.', markersize=9)


fig = plt.figure(figsize=(10,7))

plt.plot(freq_posX, peakX, 'r.', markersize=9)

freq_pos = freq[:N//2]
plt.plot(freq_pos, X_abs, label="Amplitude absolue")
plt.xlim(35, 450)  # zoom frequency
plt.ylim(0, 0.005)
plt.grid()
plt.xlabel("Fréquence (Hz)")
plt.ylabel("Amplitude |X(f)| [mm/s]_RMS")

plt.show()
fig.savefig("Spectre FFT")

# %%
df = d1["amplitude-ZP1"]
N= len(df)
y=[]
for j in range(0,(int(N/2)+1)):
    R=0    
    for i in range(0,(int(N/2))):
        R = R+ df[i]*df[i+j]
    y.append(R*2/N)
    
# Autocorrelation coefficient calculation

df = pd.DataFrame(y)
df.columns =['R']
R0=df.iloc[0,0]
R0
df['A'] = df['R']/R0
dt = d1["time"]
t=[]
for i in range(len(df)):
    t.append(dt[i])
    
df['t']=t
# Plot waveform signal
fig = plt.figure(figsize=(8,8), dpi=72)
x=d1["time"]
y2=d1["amplitude-ZP1"]
plt.plot(x,y2)
plt.xlabel("Time")
plt.ylabel("amplitude-ZP1")
plt.title("Original Signal waveform")
fig.savefig("Signal wave form.png")
plt.grid()
# Plot figure of Autocorrelation coefficient
fig1 = plt.figure(figsize=(8,8), dpi=72)
x1=df["t"]
y1=df["A"]
plt.plot(x1,y1)
plt.xlabel("Time[ms]")
plt.ylabel("Amplitude[g]")
plt.title("Autocorrelation coefficient")
fig1.savefig("Autocorrelation coefficient.png")
plt.grid()

# %%
from numpy.fft import fft, fftfreq

N=y1.size # Number of samples

Duration =0,12 # Length of the wavwform in second(Duration)
Te = 1/16384 # Sampling time

X = fft(y1)  # Fast Fourier Transform

freq = fftfreq(y1.size, 1/16384)  # Fast Fourier Transform Frequency

# Take only positif absolute value and  normalisation

X_abs = np.abs(X[:N//2])*2.0/N

freq_pos = freq[:N//2]

peakX = np.max(X_abs) # Find max peak

locX = np.argmax(X_abs) # Find its location

freq_posX = freq_pos[locX] # Get the actual frequency value

# New - Plot the max point
#plt.plot(freq_posX, peakX, 'r.', markersize=9)


fig = plt.figure(figsize=(10,7))

plt.plot(freq_posX, peakX, 'r.', markersize=9)

freq_pos = freq[:N//2]
plt.plot(freq_pos, X_abs, label="Amplitude absolue")
plt.xlim(1, 150)  # zoom frequency
plt.ylim(0, 0.03)
plt.grid()
plt.xlabel("Fréquence (Hz)")
plt.ylabel("Amplitude |X(f)| [mm/s]_RMS")

plt.show()
fig.savefig("Spectre FFT")
